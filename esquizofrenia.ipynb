# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoriverosq/esquizofrenia/blob/main/esquizofrenia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Atención de múltiples cabezas**

# %%
#Instalamos las librerías necesarias
# !pip install transformers
# !pip install bertviz
# !pip install torch
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 52.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 15.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# ...

# %%
#Importamos las librerías
from transformers import BertModel, BertTokenizer
from bertviz import head_view
import torch
import pandas as pd

# %%
#Cargamos un vanilla Bert-base model.
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# %%
texto = "I hear voices that speak to me in the night dementia"

tokens = tokenizer.encode(texto)
inputs = torch.tensor(tokens).unsqueeze(0)  #unsqueeze cambia la forma de (20, ) -> (1, 20)
print (inputs)
# Out:
# tensor([[  101,  1045,  2963,  5755,  2008,  3713,  2000,  2033,  1999,  1996,
#           2305, 28767,   102]])

# %%
attention = model(inputs, output_attentions=True) [2] #Recoge las puntuaciones de atención de BERT

# %%
#average attention in the last encoder
final_attention = attention[-1].mean(1)[0]

# %%
attention_df = pd.DataFrame(final_attention.detach()).applymap(float).round(3)

attention_df.columns = tokenizer.convert_ids_to_tokens(tokens)
attention_df.index = tokenizer.convert_ids_to_tokens(tokens)

attention_df #sums across rows add up to 1. sums across columns do not
# Out:
#           [CLS]      i   hear  voices   that  speak     to     me     in  \
# [CLS]     0.083  0.051  0.043   0.118  0.069  0.042  0.036  0.057  0.034
# i         0.029  0.048  0.025   0.014  0.023  0.012  0.011  0.025  0.017
# hear      0.015  0.012  0.087   0.018  0.010  0.017  0.010  0.010  0.014
# voices    0.017  0.010  0.022   0.092  0.015  0.021  0.015  0.010  0.014
# that      0.022  0.014  0.019   0.022  0.095  0.017  0.022  0.011  0.020
# speak     0.012  0.007  0.016   0.016  0.012  0.081  0.013  0.006  0.009
# to        0.017  0.012  0.018   0.014  0.011  0.021  0.090  0.010  0.017
# me        0.029  0.027  0.026   0.014  0.020  0.011  0.012  0.031  0.014
# in        0.023  0.013  0.020   0.016  0.016  0.014  0.020  0.015  0.075
# the       0.021  0.020  0.039   0.017  0.016  0.016  0.023  0.021  0.042
# night     0.019  0.010  0.014   0.014  0.010  0.011  0.011  0.011  0.018
# dementia  0.072  0.021  0.022   0.036  0.031  0.025  0.014  0.019  0.018
# ...

# %%
#https://www-nlp.stanford.edu/pubs/clark2019what.pdf
#Capa índice 2 parece estar atendiendo al token previo
#Capa índice 6 parece ser para pronombres

# %%
tokens_as_list = tokenizer.convert_ids_to_tokens(inputs[0])
head_view(attention, tokens_as_list)
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-7bcefb63d7f34c0980c6a71c4f026e1a" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
#Cabeza 3-1 atiende a tokens previos
head_view(attention, tokenizer.convert_ids_to_tokens(inputs[0]), layer=2, heads =[0])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-80a39ef5dc744d79a8a6c499aa4cce36" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
#Head 8-10 relaciona objetos directos a sus verbos por ejemplo me -> dijo
head_view(attention, tokenizer.convert_ids_to_tokens(inputs[0]), layer=7, heads=[9])
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-5e1eb8a9ba564e0fb279f603822553fb" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
#Atención en la décima cabeza del octavo codificador para ver la atención directa del objeto
eight_ten = attention[7] [0] [9]

# %%
#Obtener la matriz de atención
attention_df = pd.DataFrame(eight_ten.detach()).applymap(float).round(3)

attention_df.columns = tokenizer.convert_ids_to_tokens(tokens)
attention_df.index = tokenizer.convert_ids_to_tokens(tokens)

attention_df #Las sumas entre filas suman 1. Las sumas entre columnas no
# Out:
#           [CLS]      i   hear  voices   that  speak     to     me     in  \
# [CLS]     0.006  0.005  0.004   0.009  0.007  0.006  0.003  0.010  0.003
# i         0.015  0.011  0.006   0.004  0.005  0.001  0.001  0.002  0.000
# hear      0.038  0.068  0.045   0.008  0.033  0.001  0.000  0.003  0.000
# voices    0.030  0.041  0.329   0.053  0.023  0.011  0.002  0.006  0.000
# that      0.013  0.029  0.620   0.010  0.020  0.002  0.000  0.000  0.000
# speak     0.013  0.031  0.075   0.046  0.328  0.030  0.002  0.005  0.001
# to        0.008  0.006  0.016   0.013  0.439  0.268  0.060  0.009  0.003
# me        0.001  0.002  0.001   0.011  0.050  0.490  0.402  0.004  0.005
# in        0.020  0.005  0.055   0.044  0.124  0.304  0.035  0.037  0.027
# the       0.004  0.001  0.009   0.013  0.057  0.136  0.022  0.023  0.626
# night     0.006  0.004  0.004   0.012  0.030  0.019  0.004  0.055  0.174
# dementia  0.012  0.006  0.027   0.022  0.049  0.153  0.015  0.032  0.081
# ...
